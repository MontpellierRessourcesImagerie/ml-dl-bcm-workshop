# %% [markdown]
# | [![home](../media/navigation/home.png)](../index.html) | [![next](../media/navigation/next.png)](../lectures//chapter-2.html) |
# | :---: | :---: |
# | • | Chapter 2: The second chapter |

# %% [markdown]
# ## 1.1 Introduction

# %% [markdown]
# In the introduction we will revisit briefly how image analysis problems are solved without machine learning. We will then introduce machine learning and compare image analysis with and without machine learning. Interestingly we will find a number of concepts we are familiar with from image analysis before machine learning are also important when using machine learning.

# %% [markdown]
# <center>
# <img width='15%' src="../media/chapter01_01/brain_robot.png" alt="brain/robot" >
# <br>
# <small>
# Fig. 1.1 &ndash; Human vs machine.<br>(Image by Seanbatty from Pixabay)
# </small>
# </center>

# %% [markdown]
# We will introduce the basic terms that you will encounter in machine learning and finally we will illustrate the basic concept of machine learning with the smallest example possible, the ``Hello World!`` of machine learning, a linear regression.

# %% [markdown]
# ### 1.1.1 What is bio-image analysis?

# %% [markdown]
# In [[1]](#lit-ref-1) image analysis is defined as:
#
# <cite>"Image analysis is concerned with making quantitative measurements from an image
# to produce a description of it."</cite>
#
# In analogy we define bio-image analysis as:
#
# <cite>"Bio-image analysis is the extraction of information from digital images in the context of biological research."</cite>

# %% [markdown]
# <center>
# <img width='55%' src="../media/chapter01_01/analysis.png" alt="analysis" >
# <br>
# <small>
# Fig. 1.2 &ndash; Image analysis is the extraction of quantitative data from digital images.
# </small>
# </center>

# %% [markdown]
# As is illustrated in fig. 1.3, an image analysis workflow can usually be divided into different phases: pre-processing, segmentation and post-processing. In the pre-processing phase a number of filters are typically applied to the image to make the structures of interest stand out from the background. The pre-processed image is than segmented to obtain a binary mask separating the background pixels from the foreground pixels or a label image, if multiple objects need to be segmented individually. The mask is then post-processed to correct segmentation errors, often using mathematical morphology. The object or the objects defined by the post-processed mask or label image are then measured on the mask/label image and the original intensity image, to extract the data from the image.

# %% [markdown]
# <center>
# <img width='55%' src="../media/chapter01_01/workflow.png" alt="workflow" >
# <br>
# <small>
# Fig. 1.3 &ndash; A typical image analysis workflow.
# </small>
# </center>

# %% [markdown]
# One or more, but usually a small number of features are often extracted, by applying filters to the original image. The aim is to obtain features that can be combined to an image on which the segmentation is easier to accomplish than on the original image. Before the features are extracted, a scale is selected by applying a Gaussian Filter with a given sigma. The Gaussian filter replaces the value of a pixel by a weighted average of the pixels in a neighborhood around the pixel. The weights follow a Gaussian function. They become smaller with the distance from the central pixel. The Gaussian Filter is a low pass filter that will remove the high frequencies. The high frequencies represent the noise and small objects in the image. With larger sigma only even lower frequencies pass.

# %% [markdown]
# <center>
# <div style="width:60%; margin: auto;">
# <div style="width:60%;  float:left; ">
# <img src="../media/chapter01_01/gaussians.png"   alt="gaussians">
# <br>
# <small>
# Fig. 1.4 &ndash; Gaussians with different sigmas.
# </small>
# </div>
# <div style="width:25%; float:left;  ">
# <img src="../media/chapter01_01/3d_gaussian.png" alt="3d Gaussian" >
# <br>
# <small>
# Fig. 1.5 &ndash; Representation of a 3D Gaussian.
# </small>
# </div>
# </div>
# </center>

# %% [markdown]
# <center>
# <div style="width:60%; margin: auto;">
# <div style="width:60%;  float:left; ">
# <img src="../media/chapter01_01/gaussians.png"   alt="gaussians">
# <br>
# <small>
# Fig. 1.4 &ndash; Gaussians with different sigmas.
# </small>
# </div>
# <div style="width:25%; float:left;  ">
# <img src="../media/chapter01_01/3d_gaussian.png" alt="3d Gaussian" >
# <br>
# <small>
# Fig. 1.5 &ndash; Representation of a 3D Gaussian.
# </small>
# </div>
# </div>
# </center>

# %% [markdown]
# <center>
# <div style="width:60%; margin: auto;">
# <div style="width:60%;  float:left; ">
# <img src="../media/chapter01_01/gaussians.png"   alt="gaussians">
# <br>
# <small>
# Fig. 1.4 &ndash; Gaussians with different sigmas.
# </small>
# </div>
# <div style="width:25%; float:left;  ">
# <img src="../media/chapter01_01/3d_gaussian.png" alt="3d Gaussian" >
# <br>
# <small>
# Fig. 1.5 &ndash; Representation of a 3D Gaussian.
# </small>
# </div>
# </div>
# </center>

# %% [markdown]
# One kind of filters frequently used are ``convolution filters``. Convolution filters are linear filters. A convolution filter in digital image processing can be represented by a matrix with a radius $r$, called the kernel of the filter. To apply the filter to an image, the central position of the kernel is iteratively placed on each pixel of the image. A new value for that pixel is calculated, based on the values in the original image. It is calculated as the weighted sum of the values in the neighborhood with radius $r$, where the weights are the values in the kernel.
#
# It should be clear, that the Gaussian filter is a convolution filter, but there are others, for example the Laplacian filter and the Sobel filter which are used for spot and edge detection.

# %% [markdown]
# <center>
# <img width='35%' src="../media/chapter01_01/2D_Convolution_Animation.gif" alt="convolution" >
# <br>
# <small>
# Fig. 1.6 &ndash; Animation explaining the discerte 2D deconvolution.<br>(By Michael Plotke - Own work, CC BY-SA 3.0, https://commons.wikimedia.org/w/index.php?curid=24288958)
# </small>
# </center>

# %% [markdown]
# Mathematically we can express a discrete convolution of a digital 2D image $I$ with a kernel $k$ of radius $r$ as:
#
# $$
#     (I*k)(x,y) = \sum_{m=-r}^{r}\sum_{n=-r}^{r}I[x-m,y-n] \cdot k[m,n] ~~~~~~~~~~~~ (1)
# $$

# %% [markdown]
# Figure 1.7 illustrates different features at different scales. Note that the scale is the square of the sigma of the Gaussian, i.e. the variance.

# %% [markdown]
# <center>
# <img width='55%' src="../media/chapter01_01/scales.png" alt="scales" >
# <br>
# <small>
# Fig. 1.7 &ndash; Two features at 3 different scales (12.25, 49 and 100)
# </small>
# </center>

# %% [markdown]
# ### 1.1.2 Machine Learning

# %% [markdown]
# Machine learning algorithms build a mathematical model based on sample data, known as ”training data”, in order to make predictions or decisions without being explicitly programmed to perform the task.

# %% [markdown]
# <center>
# <img width='55%' src="../media/chapter01_01/model.png" alt="model" >
# <br>
# <small>
# Fig. 1.8 &ndash; A mathematical model maps input values to output values by applying functions, depending on parameters. The parameters can be modified to obtain a specific mapping.
# </small>
# </center>

# %% [markdown]
# To do machine learning, you first decide which kind of model you want to use. The model could be a mathematical function, a random forest, a neural network, or anything else that maps input values to unique output values and has parameters that can be ``tuned``.

# %% [markdown]
# <img width='15%' src="../media/chapter01_01/training.png" alt="training" >

# %% [markdown]
# In the ``training`` phase the model is learned from the training data, by modifying the parameters of the model. After the training phase follows the validation phase.

# %% [markdown]
# <img width='8%' src="../media/chapter01_01/validation.png" alt="validation" >

# %% [markdown]
# In the ``validation`` phase the model is evaluated on test data that has not been used in the training phase. When its performance is satisfactory the application phase can begin.

# %% [markdown]
# <img width='8%' src="../media/chapter01_01/application.png" alt="application" >

# %% [markdown]
# In the ``application`` phase, the trained model is used to make predictions on new data.

# %% [markdown]
# We distinguish between supervised and unsupervised training and between classification and regression models.

# %% [markdown]
# <img width='8%' src="../media/chapter01_01/supervised.png" alt="superwised" >

# %% [markdown]
# The training is called ``supervised``, when the model is trained from pairs of input and output data.

# %% [markdown]
# <img width='8%' src="../media/chapter01_01/unsupervised.png" alt="unsuperwised" >

# %% [markdown]
# The training is called ``unsupervised``, when the model is trained on the inherent structure of the input data alone.

# %% [markdown]
# <img width='8%' src="../media/chapter01_01/classification.png" alt="classification" >

# %% [markdown]
# The model is called a ``classification``-model, when the output is one of a small number of categories.

# %% [markdown]
# <img width='18%' src="../media/chapter01_01/regression.png" alt="regression" >

# %% [markdown]
# The model is called a ``regression``-model, when the output is a real number.

# %% [markdown]
# When we talk about machine learning in this workshop, what we mean is that we are trying to find the parameters of a mathematical model, that minimize the overall prediction error.

# %% [markdown]
# ### 1.1.3 The Linear Regression Example

# %% [markdown]
# # Literature

# %% [markdown]
# <a id='lit-ref-1'></a>
# 1. Jain, A.K., 1989. [Fundamentals of digital image processing](https://books.google.fr/books/about/Fundamentals_of_Digital_Image_Processing.html?id=GANSAAAAMAAJ&redir_esc=y), Prentice Hall information and system sciences series. Prentice Hall, Englewood Cliffs (N.J.).
