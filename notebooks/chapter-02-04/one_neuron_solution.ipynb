# %% [markdown]
# # Exercise 01: One Neuron

# %% [markdown]
# ## Goal

# %% [markdown]
# In this exercise you will create a model that predicts the body height of a person from the length of his femur bone. The lengths of the femur and the body height of 50 persons have been measured and are available in a csv file. We assume a linear relation between the length of the leg and the body height.
#
# You will build the most simple neural network consisting of just one neuron do do a linear regression to fit the data. You will then use the model to make predictions.
#
# What you will learn in the exercise:
#
# * How to **load data** from a table in a csv-file
# * How to **access** the loaded data
# * How to **display and plot** the data for inspection
# * How to use keras to **build a fully connected neural network** (the most simple possible in this case)
# * How to set the **optimizer** and some **hyperparameters**
# * How to **train** the network
# * How to **plot the loss** per epoch and a **metric** to evaluate the model
# * How to use the trained model to **make predictions**
#
# You can build on this when you are creating more complex models later.

# %% [markdown]
# ## Exercise
#
# Write the code in the empty cells below, following the instructions and execute them. The cells that are already filled in, you just have to execute (shift + enter).

# %% [markdown]
# The next cell switches of warnings, so that we do not get distracted by them.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We import the python modules we will use in the exercise.
#
# * **keras:** Create and use ANNs.
# * **pyplot:** Create plots.
# * **pandas:** Data analysis, we use it to handle the input data, that comes as a table in a csv-file
# * **numpy:** Multidimensional arrays
#
# The ``as``keyword is used to rename the module, so that we do not have to write the long name when we use it.
#
# We format the output of numbers to a precision of 3 digits and suppress the usage of scientific notation.
#
# We print the version number of keras (for debugging purposes, in case we will encounter errors)

# %%
import keras
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

np.set_printoptions(precision=3, suppress=True)
print(keras.__version__)
# Out:
# 3.3.3

# %% [markdown]
# ## Exercise. 1.1
#
# We can use pandas to read from a local file or from an url. The commands is:
#
# * ```pd.read_csv(pathOrURL)```
#
# In the next cell load the file ``leg.csv`` from the url: https://dev.mri.cnrs.fr/attachments/download/3341/leg.csv
#
# Once the data loaded, display a part of it. You can display the first or last n lines of the table using the commands:
#
# * ```data.head(n)```
# * ```data.tail(n)```

# %%
data = pd.read_csv("https://dev.mri.cnrs.fr/attachments/download/3341/leg.csv")
data.head(10)
# Out:
#   Sample  Nr  Length  Height
# 0    Leg   1   58.42  102.87
# 1    Leg   2   50.80  101.60
# 2    Leg   3   53.34  100.33
# 3    Leg   4   50.80  101.60
# 4    Leg   5   50.80   99.06
# 5    Leg   6   53.34  101.60
# 6    Leg   7   55.88  109.22
# 7    Leg   8   53.34  104.14
# 8    Leg   9   50.80  105.41
# 9    Leg  10   55.88  111.76

# %% [markdown]
# ## Exercise 1.2
#
# Plot the height on the y-axis against the length on the x-axis, to see how the points are distributed.
#
# You can access a column in the table using ```data['column_name']```. The command to create a plot containing points is
#
# ```plt.plot(X, Y, 'ro')```
#
# The command to display a plot is ```plt.show```.

# %%
plt.plot(data['Length'], data['Height'], 'ro')
plt.show()

# %% [markdown]
# ## Exercise 1.3
#
# Now that we have loaded and inspected the data, we will create the neural network.
#
# Use ```keras.Sequential(list_of_layers)``` to create the the network and assign it to the variable ```model```. To create a fully connected network we use dense layers. A dense layer is created with
#
# <code>
#    keras.layers.Dense(units=nr_of_units_in_the_layer,
#                       input_shape=list_of_input_size_per_dimension,
#                       activation="name_of_the_activation_function")
# </code>
#
#
# The input is a single number in our case. Since we do regression, we use the linear activation function.
#
# Use ```model.summary()``` to display a summary of the model.

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=(1,), activation="linear")])    
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 1)              │             2 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2 (8.00 B)
#  Trainable params: 2 (8.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Exercise 1.4
#
# Compile the model and set the optimizer, the loss function and an additional metric, to validate the model.
# First create an Adam optimizer using
#
# ```keras.optimizer.Name_Of_The_Optimizer(learning_rate=rate)``` and assign it to a variable ```opt```.
#
# Use the ```"mean_squared_error"``` as loss function and let the model calculate the additional ```"R2Score"``` metric.
#
# The command to compile the model is:
#
# ```model.compile(optimizer=opt, loss='name_of_loss_function', metrics=list_of_metrics)```

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.04)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['R2Score'])

# %% [markdown]
# ## Exercise 1.5
#
# Now train the model with the input data. The input data is the length column of the table and the corresponding ground truth data is the height column. The command to train the model is:
#
# ```model.fit(input_data, ground_truth_data, epochs=nr_of_epochs)```
#
# Assign the result of the fit to a variable ```history```, so that we can plot the loss and the R2Score later.

# %%
history = model.fit(data['Length'], data['Height'], epochs=60)
# Out:
# Epoch 1/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - R2Score: -53.8671 - loss: 19152.2578
# Epoch 2/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -44.5912 - loss: 17971.7930
# Epoch 3/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - R2Score: -44.6532 - loss: 16235.2637
# Epoch 4/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -39.1863 - loss: 15006.5996
# Epoch 5/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -34.0310 - loss: 13644.9365
# Epoch 6/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -32.3594 - loss: 12426.6426
# Epoch 7/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -29.6895 - loss: 11255.1846
# Epoch 8/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -25.2652 - loss: 10276.1924
# Epoch 9/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -24.2890 - loss: 9454.6006
# Epoch 10/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -21.1658 - loss: 8349.8936
# Epoch 11/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -18.8420 - loss: 7516.5391
# Epoch 12/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -16.4568 - loss: 6533.0405
# Epoch 13/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -15.1422 - loss: 5880.8784
# Epoch 14/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -13.8198 - loss: 5203.9790
# Epoch 15/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -11.2308 - loss: 4569.6611
# Epoch 16/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -9.7930 - loss: 3955.7239
# Epoch 17/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -9.1426 - loss: 3430.7024
# Epoch 18/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -6.9196 - loss: 2977.9370
# Epoch 19/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -6.2903 - loss: 2547.6423
# Epoch 20/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -4.8844 - loss: 2180.5403
# Epoch 21/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -4.5515 - loss: 1791.4515
# Epoch 22/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -3.4539 - loss: 1577.6372
# Epoch 23/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -2.5642 - loss: 1344.7393
# Epoch 24/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -1.9735 - loss: 1111.2218
# Epoch 25/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -1.6460 - loss: 927.5930
# Epoch 26/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -1.0272 - loss: 740.8121
# Epoch 27/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -0.5649 - loss: 604.3383
# Epoch 28/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -0.4204 - loss: 507.9728
# Epoch 29/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: -0.0318 - loss: 396.8499
# Epoch 30/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.1122 - loss: 341.8081
# Epoch 31/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.2789 - loss: 275.0008
# Epoch 32/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.3376 - loss: 220.1343
# Epoch 33/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.5458 - loss: 172.8703
# Epoch 34/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.5734 - loss: 148.6355
# Epoch 35/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.6992 - loss: 113.8736
# Epoch 36/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.7480 - loss: 99.1432
# Epoch 37/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.7880 - loss: 76.9556
# Epoch 38/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8228 - loss: 65.7050
# Epoch 39/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8394 - loss: 60.7041
# Epoch 40/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - R2Score: 0.8281 - loss: 58.1151
# Epoch 41/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8493 - loss: 55.0925
# Epoch 42/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8685 - loss: 51.1437
# Epoch 43/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8727 - loss: 50.1613
# Epoch 44/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8520 - loss: 50.7526
# Epoch 45/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - R2Score: 0.8928 - loss: 40.9486
# Epoch 46/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - R2Score: 0.8779 - loss: 47.5180
# Epoch 47/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8680 - loss: 53.4365
# Epoch 48/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8910 - loss: 41.2909
# Epoch 49/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8796 - loss: 47.3935
# Epoch 50/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8777 - loss: 46.6289
# Epoch 51/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8753 - loss: 49.0211
# Epoch 52/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - R2Score: 0.8687 - loss: 47.1008
# Epoch 53/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8543 - loss: 51.8410
# Epoch 54/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - R2Score: 0.8754 - loss: 48.9576
# Epoch 55/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8754 - loss: 45.1745
# Epoch 56/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8580 - loss: 53.0020
# Epoch 57/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8781 - loss: 44.9980
# Epoch 58/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8591 - loss: 47.5930
# Epoch 59/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - R2Score: 0.8618 - loss: 51.1422
# Epoch 60/60
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - R2Score: 0.8788 - loss: 45.1156

# %% [markdown]
# We plot the loss per epoch.

# %%
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper right')
plt.show()

# %% [markdown]
# We plot the R2 score per epoch.

# %%
plt.plot(history.history['R2Score'])
plt.title('R2 score')
plt.ylabel('r2')
plt.xlabel('epoch')
plt.legend(['train'], loc='lower right')
plt.show()

# %% [markdown]
# We plot the data points like before and add the learned linear model.

# %%
plt.plot(data['Length'], data['Height'], 'ro', data['Length'], model.predict(data['Length']), '-')
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# ## Exercise 1.6
#
# Use the trained model to predict the body heights for the leg lengths 30, 75 and 110. The command is
#
# ```model.predict(values)```, where values is a numpy array that can be created from a list of values with ```np.array(list_of_Values)```.

# %%
model.predict(np.array([30, 75, 110]))
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f776050a820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# array([[ 58.303],
#        [144.863],
#        [212.187]], dtype=float32)
