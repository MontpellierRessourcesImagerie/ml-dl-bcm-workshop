# %% [markdown]
# | [![back](../../media/navigation/previous.png)](../../exercises/chapter-01/ex1.html) | [![home](../../media/navigation/home.png)](../../index.html) | [![next](../../media/navigation/next.png)](../../exercises/chapter-01/ex3.html) |
# | :---: | :---: | :---: |
# | Ex 3.2.1: Segment & track yeasts | • | Ex 3.2.3: Evaluate nuclear-cytoplasmic translocation |

# %% [markdown]
# ## 1.2 ..

# %% [markdown]
# Aim:
#  - ...
